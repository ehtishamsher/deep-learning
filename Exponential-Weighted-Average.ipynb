# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DailyDelhiClimate.csv")

# %%
df = df[['date','meantemp']]
df
# Out:
#             date   meantemp
# 0     2013-01-01  10.000000
# 1     2013-01-02   7.400000
# 2     2013-01-03   7.166667
# 3     2013-01-04   8.666667
# 4     2013-01-05   6.000000
# ...          ...        ...
# 1571  2017-04-20  34.500000
# 1572  2017-04-21  34.250000
# 1573  2017-04-22  32.900000
# 1574  2017-04-23  32.875000
# 1575  2017-04-24  32.000000
#
# [1576 rows x 2 columns]

# %%
plt.scatter(df['date'], df['meantemp'],color= 'red')

# %%
X1 = df['meantemp'].ewm(alpha=0.6).mean()

# %%
X1
# Out:
# 0       10.000000
# 1        8.142857
# 2        7.517094
# 3        8.224959
# 4        6.876172
#           ...
# 1571    34.045229
# 1572    34.168092
# 1573    33.407237
# 1574    33.087895
# 1575    32.435158
# Name: meantemp, Length: 1576, dtype: float64

# %%
df['ewma'] = X1
df
# Out:
#             date   meantemp       ewma
# 0     2013-01-01  10.000000  10.000000
# 1     2013-01-02   7.400000   8.142857
# 2     2013-01-03   7.166667   7.517094
# 3     2013-01-04   8.666667   8.224959
# 4     2013-01-05   6.000000   6.876172
# ...          ...        ...        ...
# 1571  2017-04-20  34.500000  34.045229
# 1572  2017-04-21  34.250000  34.168092
# 1573  2017-04-22  32.900000  33.407237
# 1574  2017-04-23  32.875000  33.087895
# 1575  2017-04-24  32.000000  32.435158
#
# [1576 rows x 3 columns]

# %%
plt.scatter(df['date'], df['meantemp'],color='red')
plt.plot(df['date'], df['ewma'], color='black',label = 'alpha = 0.9')
